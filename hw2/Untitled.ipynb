# %%
#將資料化為易讀形式並印出
import json
import pprint as pp

with open('covid.json', encoding='utf-8') as file:
    data = json.load(file)

pp.pprint(data, sort_dicts=False)
# Out:
# [{'UID': 29546,
#   '個案研判日': '2022-12-31',
#   '縣市別': '全國',
#   '區域': '全區',
#   '新增確診人數': 25382,
#   'total': 8872579,
#   '七天移動平均新增確診人數': 24757.14},
#  {'UID': 29912,
#   '個案研判日': '2022-12-30',
#   '縣市別': '全國',
#   '區域': '全區',
#   '新增確診人數': 25751,
#   'total': 8847197,
#   '七天移動平均新增確診人數': 23662.86},
#  {'UID': 30284,
#   '個案研判日': '2022-12-29',
#   '縣市別': '全國',
#   '區域': '全區',
#   '新增確診人數': 27378,
#   'total': 8821446,
#   '七天移動平均新增確診人數': 22563.71},
#  {'UID': 30657,
#   '個案研判日': '2022-12-28',
#   '縣市別': '全國',
#   '區域': '全區',
#   '新增確診人數': 27921,
#   'total': 8794068,
#   '七天移動平均新增確診人數': 21376.14},
#  {'UID': 31027,
#   '個案研判日': '2022-12-27',
#   '縣市別': '全國',
#   '區域': '全區',
#   '新增確診人數': 28150,
#   'total': 8766147,
#   '七天移動平均新增確診人數': 20226.86},
#  {'UID': 31404,
#   '個案研判日': '2022-12-26',
#   '縣市別': '全國',
#   '區域': '全區',
#   '新增確診人數': 24486,
#   'total': 8737997,
#   '七天移動平均新增確診人數': 18939.86},
#  {'UID': 31776,
#   '個案研判日': '2022-12-25',
#   '縣市別': '全國',
#   '區域': '全區',
# ...
