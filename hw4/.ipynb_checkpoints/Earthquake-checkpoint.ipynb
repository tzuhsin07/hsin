# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.15.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\.ms-ad\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\users\user\.ms-ad\lib\site-packages (from folium) (2.27.1)
# Collecting branca>=0.6.0
#   Downloading branca-0.7.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in c:\users\user\.ms-ad\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\.ms-ad\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\.ms-ad\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\.ms-ad\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\.ms-ad\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\.ms-ad\lib\site-packages (from requests->folium) (2021.10.8)
# Installing collected packages: branca, folium
# Successfully installed branca-0.7.0 folium-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
import pandas as pd
df_earthquake = pd.read_csv('earthquake.csv',encoding="big5")
df_earthquake.head()
# Out:
#    2023年1月           Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  小區域有感地震  2023-01-29 23:15:18      120.80       23.21         3.2
# 1  小區域有感地震  2023-01-27 06:40:39      121.24       23.27         3.5
# 2  小區域有感地震  2023-01-24 22:37:26      121.28       23.07         3.7
# 3  小區域有感地震  2023-01-24 12:17:01      121.29       23.44         3.8
# 4  小區域有感地震  2023-01-22 06:13:07      121.91       24.43         3.6
#
#    Unnamed: 5                              Unnamed: 6
# 0         4.7   高雄市政府東北方  81.9  公里 (位於高雄市桃源區)(高雄市桃源區)
# 1        16.8  花蓮縣政府南南西方  89.2  公里 (位於花蓮縣卓溪鄉)(花蓮縣卓溪鄉)
# 2         7.7  臺東縣政府北北東方  37.3  公里 (位於臺東縣東河鄉)(臺東縣東河鄉)
# 3        11.4  花蓮縣政府南南西方  70.0  公里 (位於花蓮縣卓溪鄉)(花蓮縣卓溪鄉)
# 4        13.4  宜蘭縣政府南南東方  36.5  公里 (位於臺灣東部海域)(臺灣東部海域)

# %%
folium.Marker(location=[df_earthquake['Unnamed: 3'][1], df_earthquake['Unnamed: 2'][1]]).add_to(m)
folium.Marker(location=[df_earthquake['Unnamed: 3'][2], df_earthquake['Unnamed: 2'][2]]).add_to(m)
folium.Marker(location=[df_earthquake['Unnamed: 3'][3], df_earthquake['Unnamed: 2'][3]]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_506df24632dd1132b2832bca31bd22ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_506df24632dd1132b2832bca31bd22ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_506df24632dd1132b2832bca31bd22ef = L.map(
#                 &quot;map_506df24632dd1132b2832bca31bd22ef&quot;,
#                 {
#                     center: [23.5, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcb78d90a2989229e71f6462f859215f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_bcb78d90a2989229e71f6462f859215f.addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#             var marker_d68e822e74a6b1281a1895dfe58f13da = L.marker(
#                 [120.798, 23.2082],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_959151d7964c6554488da9e9d86e531b = L.marker(
#                 [121.238, 23.2665],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_33783cf5534574b35a2bde3e4978f77d = L.marker(
#                 [121.276, 23.0717],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_bcada811d80551ed641f749e4b380fa2 = L.marker(
#                 [120.798, 23.2082],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_42777cfe20bf78e857f1a2a0b73b0cf9 = L.marker(
#                 [121.238, 23.2665],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_11560fad1d09513579262e6b91aeb386 = L.marker(
#                 [121.276, 23.0717],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_cf619e433e032aa794c00acb61d0cb0b = L.marker(
#                 [23.2082, 120.798],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_79738871608ee14eb1ea01aa54f37369 = L.marker(
#                 [23.2665, 121.238],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
#
#             var marker_f4f9478a0b52d89cfa9227c57d3b01d9 = L.marker(
#                 [23.0717, 121.276],
#                 {}
#             ).addTo(map_506df24632dd1132b2832bca31bd22ef);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m0 = folium.Map([23.5, 121], zoom_start=7,tiles='OpenStreetMap')
for index, row in df_earthquake.iterrows():
    folium.Marker(location=[row['Unnamed: 3'],row['Unnamed: 2']]).add_to(m0)
m0
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bf1bc6ac2a1f2c2bfb5c09b798cac47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bf1bc6ac2a1f2c2bfb5c09b798cac47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5bf1bc6ac2a1f2c2bfb5c09b798cac47 = L.map(
#                 &quot;map_5bf1bc6ac2a1f2c2bfb5c09b798cac47&quot;,
#                 {
#                     center: [23.5, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49717964b9569ae140462ddd904d725b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_49717964b9569ae140462ddd904d725b.addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#             var marker_4126ceb6e4d5ccaab09c343451ee5909 = L.marker(
#                 [23.21, 120.8],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_2fe2296cc53205810d93e93c325fc07e = L.marker(
#                 [23.27, 121.24],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_e762632e9c84368a3d237f177ff69cd8 = L.marker(
#                 [23.07, 121.28],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_e027311e875e5cab161d25227a8efc31 = L.marker(
#                 [23.44, 121.29],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_0dd807bc63eb14f8ef8ad699f932902b = L.marker(
#                 [24.43, 121.91],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_cdeb28201bb74d04ad7b7db88345fdd4 = L.marker(
#                 [24.38, 120.86],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_63af83206cd52e43f633ca5241f0f05e = L.marker(
#                 [23.26, 121.24],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_63cbc89f845d35b4081318834694ed0b = L.marker(
#                 [23.78, 121.77],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_df520cf682f9d67bdcd04f60f3dab164 = L.marker(
#                 [23.25, 120.27],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_3bb20f2578bbfedcfcd3fa5d180d7827 = L.marker(
#                 [24.05, 121.52],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_4f27b66bd5dca182dbdbd850720e0c48 = L.marker(
#                 [24.07, 121.78],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_14a32d4d34f259f341ab458f745886d5 = L.marker(
#                 [23.1, 121.16],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_4decb971da25714531f063d2b7a2756c = L.marker(
#                 [24.01, 122.33],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_6206053e82382e575b2a612ec7fe9522 = L.marker(
#                 [24.91, 121.16],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_7bf2951935a48e82338e7e187ce8971f = L.marker(
#                 [25.19, 122.58],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_69a52fc8ef2d2a8f1c5ae6a781aa2e30 = L.marker(
#                 [23.84, 121.69],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_7dacee3128adf5ffc0ba6a85d5079171 = L.marker(
#                 [24.32, 121.7],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_da2daa03f44e4f233b10c6b25a759690 = L.marker(
#                 [24.04, 122.34],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_0b7ad8bd008ed31776058c0f1f5bc96d = L.marker(
#                 [24.4, 121.86],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_0856da82ade42643d28634a81e52e5b1 = L.marker(
#                 [22.83, 120.66],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798cac47);
#
#
#             var marker_344a531989f12ea05f8181a0fa2c3964 = L.marker(
#                 [22.07, 121.04],
#                 {}
#             ).addTo(map_5bf1bc6ac2a1f2c2bfb5c09b798ca

# %%
m1 = folium.Map([23.5, 121], zoom_start=7)
from folium.plugins import MarkerCluster
marker_cluster = MarkerCluster().add_to(m1)

for index, row in df_earthquake.iterrows():
    if row['Unnamed: 5'] >=4.5 :
        information = str(row['Unnamed: 1'])+'<br>'+str(row['Unnamed: 5'])+'<br>'+str(row['Unnamed: 6'])
        folium.Marker(
            location=[row['Unnamed: 3'],row['Unnamed: 2']],
            
            popup=information).add_to(marker_cluster)
        
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2299833d626ebd0641e5b6986f38c803 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2299833d626ebd0641e5b6986f38c803&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2299833d626ebd0641e5b6986f38c803 = L.map(
#                 &quot;map_2299833d626ebd0641e5b6986f38c803&quot;,
#                 {
#                     center: [23.5, 121.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd47cfef2ac2dffa0713a31bdce886f8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_dd47cfef2ac2dffa0713a31bdce886f8.addTo(map_2299833d626ebd0641e5b6986f38c803);
#
#             var marker_cluster_c55a80a728b8bbc7d03486556e72a088 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_2dff867ed997c3d0bf3bed6ca04a9afc = L.marker(
#                 [23.21, 120.8],
#                 {}
#             ).addTo(marker_cluster_c55a80a728b8bbc7d03486556e72a088);
#
#
#         var popup_d65b993292e79a8d9d430d17725f9fb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b07a31dd4800e93b942c5e1b4a5ff442 = $(`&lt;div id=&quot;html_b07a31dd4800e93b942c5e1b4a5ff442&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-01-29 23:15:18&lt;br&gt;4.7&lt;br&gt;高雄市政府東北方  81.9  公里 (位於高雄市桃源區)(高雄市桃源區)&lt;/div&gt;`)[0];
#                 popup_d65b993292e79a8d9d430d17725f9fb3.setContent(html_b07a31dd4800e93b942c5e1b4a5ff442);
#
#
#
#         marker_2dff867ed997c3d0bf3bed6ca04a9afc.bindPopup(popup_d65b993292e79a8d9d430d17725f9fb3)
#         ;
#
#
#
#
#             var marker_0286bd428f5e7f8768dca1f2f18114d5 = L.marker(
#                 [23.27, 121.24],
#                 {}
#             ).addTo(marker_cluster_c55a80a728b8bbc7d03486556e72a088);
#
#
#         var popup_d39d1a579b1b55ab058c78dd26db14e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf7feafe6acc3616ffc5ee83d252f8c6 = $(`&lt;div id=&quot;html_bf7feafe6acc3616ffc5ee83d252f8c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-01-27 06:40:39&lt;br&gt;16.8&lt;br&gt;花蓮縣政府南南西方  89.2  公里 (位於花蓮縣卓溪鄉)(花蓮縣卓溪鄉)&lt;/div&gt;`)[0];
#                 popup_d39d1a579b1b55ab058c78dd26db14e2.setContent(html_bf7feafe6acc3616ffc5ee83d252f8c6);
#
#
#
#         marker_0286bd428f5e7f8768dca1f2f18114d5.bindPopup(popup_d39d1a579b1b55ab058c78dd26db14e2)
#         ;
#
#
#
#
#             var marker_650d0fb0731760551412d747b0b82bc8 = L.marker(
#                 [23.07, 121.28],
#                 {}
#             ).addTo(marker_cluster_c55a80a728b8bbc7d03486556e72a088);
#
#
#         var popup_05a79f4f85a3649eee54b84c8c73ba34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0494ec89d55e48850ce28616b393932b = $(`&lt;div id=&quot;html_0494ec89d55e48850ce28616b393932b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-01-24 22:37:26&lt;br&gt;7.7&lt;br&gt;臺東縣政府北北東方  37.3  公里 (位於臺東縣東河鄉)(臺東縣東河鄉)&lt;/div&gt;`)[0];
#                 popup_05a79f4f85a3649eee54b84c8c73ba34.setContent(html_0494ec89d55e48850ce28616b393932b);
#
#
#
#         marker_650d0fb0731760551412d747b0b82bc8.bindPopup(popup_05a79f4f85a3649eee54b84c8c73ba34)
#         ;
#
#
#
#
#             var marker_68c9e353bd2586011b169cd4fdf8563f = L.marker(
#                 [23.44, 121.29],
#                 {}
#             ).addTo(marker_cluster_c55a80a728b8bbc7d03486556e72a088);
#
#
#         var popup_e065bbab97cc1ce3f2de0a1e16815f66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4137beeeb6e60be6be2f2b6cc8268fe9 = $(`&lt;div id=&quot;html_4137beeeb6e60be6be2f2b6cc8268fe9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-01-24 12:17:01&lt;br&gt;11.4&lt;br&gt;花蓮縣政府南南西方  70.0  公里 (位於花蓮縣卓溪鄉)(花蓮縣卓溪鄉)&lt;/div&gt;`)[0];
#                 popup_e065bbab97cc1ce3f2de0a1e16815f66.setContent(html_4137beeeb6e60be6be2f2b6cc8268fe9);
#
#
#
#         marker_68c9e353bd2586011b169cd4fdf8563f.bindPopup(popup_e065bbab97cc1ce3f2de0a1e16815f66)
#         ;
