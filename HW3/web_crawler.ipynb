# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

url ="https://www.ptt.cc/bbs/NBA/index.html"
response = requests.get(url)

#判斷網頁是否存在
if response.status_code == 200 :
    print(response.text)
else:
    print("網頁不存在")
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
#反爬蟲(伺服器用來阻擋爬蟲的手段)使用 Headers
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36"}
response1 = requests.get(url,headers=headers)
print(response1.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# ...

# %%
pip install beautifulSoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import json

url ="https://www.ptt.cc/bbs/NBA/index.html"
response = requests.get(url)
soup = BeautifulSoup(response.text,"html.parser") #Beautiful Soup 解析 HTML 
articles = soup.find_all("div",class_="r-ent")

data_list = []
data={}
for a in articles:
    title = a.find("div",class_="title")
    #print(title.a.text)
    data["名稱"] = title.a.text
    popular = a.find("div",class_="nrec")
    if popular and popular.span:
        popular = popular.span.text
        #print("熱度:",popular)
        data["熱度"] = popular
    date = a.find("div",class_="date")
    #print("日期:",date.text)
    data["日期"] = date.text
    data_list.append(data)
    print(data_list)
# Out:
# [{'名稱': '[BOX ] Hawks 110:116 Hornets 數據', '熱度': '33', '日期': '10/26'}]
# [{'名稱': '[BOX ] Timberwolves 94:97 Raptors 數據', '熱度': '28', '日期': '10/26'}, {'名稱': '[BOX ] Timberwolves 94:97 Raptors 數據', '熱度': '28', '日期': '10/26'}]
# [{'名稱': '[Live] 拓荒者 @ 快艇', '熱度': '9', '日期': '10/26'}, {'名稱': '[Live] 拓荒者 @ 快艇', '熱度': '9', '日期': '10/26'}, {'名稱': '[Live] 拓荒者 @ 快艇', '熱度': '9', '日期': '10/26'}]
# [{'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}, {'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}, {'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}, {'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}]
# [{'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}]
# ...

# %%
import requests
from bs4 import BeautifulSoup
import json

url ="https://www.ptt.cc/bbs/NBA/index.html"
response = requests.get(url)
soup = BeautifulSoup(response.text,"html.parser") #Beautiful Soup 解析 HTML 
articles = soup.find_all("div",class_="r-ent")

data_list = []
data={}
for a in articles:
    title = a.find("div",class_="title")
    #print(title.a.text)
    data["名稱"] = title.a.text
    popular = a.find("div",class_="nrec")
    if popular and popular.span:
        popular = popular.span.text
        #print("熱度:",popular)
        data["熱度"] = popular
    date = a.find("div",class_="date")
    #print("日期:",date.text)
    data["日期"] = date.text
    data_list.append(data)
    print(data_list)
    
with open ("NBA_ptt.json","w",encoding="utf-8") as file:
    json.dump(data_list,file, ensure_ascii=False,indent=4)
# Out:
# [{'名稱': '[BOX ] Hawks 110:116 Hornets 數據', '熱度': '33', '日期': '10/26'}]
# [{'名稱': '[BOX ] Timberwolves 94:97 Raptors 數據', '熱度': '28', '日期': '10/26'}, {'名稱': '[BOX ] Timberwolves 94:97 Raptors 數據', '熱度': '28', '日期': '10/26'}]
# [{'名稱': '[Live] 拓荒者 @ 快艇', '熱度': '9', '日期': '10/26'}, {'名稱': '[Live] 拓荒者 @ 快艇', '熱度': '9', '日期': '10/26'}, {'名稱': '[Live] 拓荒者 @ 快艇', '熱度': '9', '日期': '10/26'}]
# [{'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}, {'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}, {'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}, {'名稱': '[BOX ] Celtics 108:104 Knicks 數據', '熱度': '47', '日期': '10/26'}]
# [{'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}, {'名稱': '[花邊] NBA x One Piece', '熱度': '52', '日期': '10/26'}]
# ...

# %%
import requests
from bs4 import BeautifulSoup
import json

url ="https://www.ptt.cc/bbs/NBA/index.html"
response = requests.get(url)
soup = BeautifulSoup(response.text,"html.parser") #Beautiful Soup 解析 HTML 
articles = soup.find_all("div",class_="r-ent")


for a in articles:
    title = a.find("div",class_="title")
    print(title.a.text)
    
    popular = a.find("div",class_="nrec")
    if popular and popular.span:
        popular = popular.span.text
        print("熱度:",popular)
        
    date = a.find("div",class_="date")
    print("日期:",date.text)
# Out:
# [BOX ] Hawks 110:116 Hornets 數據
# 熱度: 33
# 日期: 10/26
# [BOX ] Timberwolves 94:97 Raptors 數據
# 熱度: 28
# 日期: 10/26
# [Live] 拓荒者 @ 快艇
# 熱度: 9
# 日期: 10/26
# [BOX ] Celtics 108:104 Knicks 數據
# 熱度: 47
# 日期: 10/26
# [花邊] NBA x One Piece
# 熱度: 52
# 日期: 10/26
# [花邊] Cam Thomas創下替補球員開幕戰的得分紀錄
# 熱度: 6
# 日期: 10/26
# [BOX ] Cavaliers 114:113 Nets 數據
# 熱度: 54
# 日期: 10/26
# [BOX ] Pistons 102:103 Heat 數據
# 熱度: 39
# 日期: 10/26
# [BOX ] Thunder 124:104 Bulls 數據
# 熱度: 68
# 日期: 10/26
# [BOX ] Pelicans 111:104 Grizzlies 數據
# 熱度: 16
# 日期: 10/26
# [花邊] 如何處理鬍子 勇士前總管:我會去問鉛筆
# 日期: 10/26
# [公告] 板規10.1
# 日期: 11/29
# [情報] 2023年 季中錦標賽 對戰圖
# 熱度: 10
# 日期: 10/03
# [情報] 2023-24賽季 例行賽賽程 (十月、十一月)
# 熱度: 17
# 日期: 10/14
# [公告] NBA 板 開始舉辦樂透!
# 熱度: 13
# 日期: 10/25
# [情報] NBA Standings (Oct. 25, 2023)
# 熱度: 24
# 日期: 10/25
